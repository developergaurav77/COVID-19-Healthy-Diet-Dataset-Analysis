# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# This dataset includes percentage of fat intake from different types of food in countries around the world. The last couple of columns
# <br>
# also includes counts of obesity, undernourished, and COVID-19 cases as percentages of the total population for comparison purposes.
# <br>
# <br>
# Alcoholic Beverages- Percentage of fat intake from alcoholic beverages
# <br>
# Animal Products- Percentage of fat intake from animal products
# <br>
# Animal fats- Percentage of fat intake from animal fats
# <br>
# Aquatic Products, Other - Percentage of fat intake from aquatic products
# <br>
# Cereals - Excluding Beer
# Percentage of fat intake from cereals - excluding beer
# <br>
# Eggs
# Percentage of fat intake from eggs
# <br>
# Fish, Seafood
# Percentage of fat intake from fish, seafood
# <br>
# Fruits - Excluding Wine
# Percentage of fat intake from fruits - excluding wine
# <br>
# Meat
# Percentage of fat intake from meat

# %%
df = pd.read_csv(r'covid-healthy-diet-dataset/Fat_Supply_Quantity_Data.csv')

# %%
df
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
df.isnull().sum()
# Out:
# Country                         0
# Alcoholic Beverages             0
# Animal Products                 0
# Animal fats                     0
# Aquatic Products, Other         0
# Cereals - Excluding Beer        0
# Eggs                            0
# Fish, Seafood                   0
# Fruits - Excluding Wine         0
# Meat                            0
# Miscellaneous                   0
# Milk - Excluding Butter         0
# Offals                          0
# Oilcrops                        0
# Pulses                          0
# Spices                          0
# Starchy Roots                   0
# Stimulants                      0
# Sugar Crops                     0
# Sugar & Sweeteners              0
# Treenuts                        0
# Vegetal Products                0
# Vegetable Oils                  0
# Vegetables                      0
# Obesity                         3
# Undernourished                  7
# Confirmed                       6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       170 non-null    object
#  1   Alcoholic Beverages           170 non-null    float64
#  2   Animal Products               170 non-null    float64
#  3   Animal fats                   170 non-null    float64
#  4   Aquatic Products, Other       170 non-null    float64
#  5   Cereals - Excluding Beer      170 non-null    float64
#  6   Eggs                          170 non-null    float64
#  7   Fish, Seafood                 170 non-null    float64
#  8   Fruits - Excluding Wine       170 non-null    float64
#  9   Meat                          170 non-null    float64
#  10  Miscellaneous                 170 non-null    float64
#  11  Milk - Excluding Butter       170 non-null    float64
# ...

# %%
df.sort_values(by='Alcoholic Beverages',ascending=False)[['Country','Alcoholic Beverages']].head(10)
# Out:
#              Country  Alcoholic Beverages
# 82      Korea, South               0.0976
# 168           Zambia               0.0783
# 0        Afghanistan               0.0000
# 117         Pakistan               0.0000
# 109    New Caledonia               0.0000
# 110      New Zealand               0.0000
# 111        Nicaragua               0.0000
# 112            Niger               0.0000
# 113          Nigeria               0.0000
# 114  North Macedonia               0.0000

# %%
#top 10 countriesthat take highest Percentage of fat from animal products
animal_product = df.sort_values(by='Animal Products',ascending=False)[['Country','Animal Products']].head(10)

# %%
animal_product
# Out:
#          Country  Animal Products
# 101     Mongolia          36.9018
# 50       Finland          36.7250
# 39       Denmark          35.4131
# 67       Iceland          34.4402
# 110  New Zealand          34.1264
# 129  Saint Lucia          33.3454
# 166      Vietnam          33.2484
# 46       Estonia          33.2190
# 135       Serbia          33.0354
# 102   Montenegro          32.7855

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Country',y='Animal Products',data=animal_product)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Animal Products'>

# %%
df.columns
# Out:
# Index(['Country', 'Alcoholic Beverages', 'Animal Products', 'Animal fats',
#        'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs',
#        'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Miscellaneous',
#        'Milk - Excluding Butter', 'Offals', 'Oilcrops', 'Pulses', 'Spices',
#        'Starchy Roots', 'Stimulants', 'Sugar Crops', 'Sugar & Sweeteners',
#        'Treenuts', 'Vegetal Products', 'Vegetable Oils', 'Vegetables',
#        'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered',
#        'Active', 'Population', 'Unit (all except Population)'],
#       dtype='object')

# %%
#top 10 countries that take highest Percentage of fat from Vegetable Oils
vegetable_oils = df.sort_values(by='Vegetable Oils',ascending=False)[['Country','Vegetable Oils']].head(10)

# %%
vegetable_oils
# Out:
#            Country  Vegetable Oils
# 89         Liberia         36.4186
# 136   Sierra Leone         34.0479
# 134        Senegal         33.0391
# 40        Djibouti         31.4490
# 151           Togo         30.6430
# 61          Guinea         30.6133
# 62   Guinea-Bissau         30.3288
# 113        Nigeria         30.1494
# 99       Mauritius         29.9945
# 11      Bangladesh         29.6422

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Country',y='Vegetable Oils',data=vegetable_oils)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Vegetable Oils'>

# %%
dfCorr = df.corr()
filteredDf = dfCorr[((dfCorr >= .5) | (dfCorr <= -.5)) & (dfCorr !=1.000)]
plt.figure(figsize=(30,10))
sns.heatmap(filteredDf, annot=True, cmap="Reds")
plt.show()

# %%
def corrFilter(x: pd.DataFrame, bound: float):
    xCorr = x.corr()
    xFiltered = xCorr[((xCorr >= bound) | (xCorr <= -bound)) & (xCorr !=1.000)]
    xFlattened = xFiltered.unstack().sort_values(ascending=False).drop_duplicates()
    return xFlattened

corrFilter(df,.5)
# Out:
# Confirmed                Deaths                     0.861348
#                          Recovered                  0.820948
# Alcoholic Beverages      Aquatic Products, Other    0.751401
# Meat                     Animal Products            0.736789
# Animal fats              Animal Products            0.686830
# Vegetable Oils           Vegetal Products           0.674503
# Recovered                Deaths                     0.671801
# Milk - Excluding Butter  Animal Products            0.609437
# Confirmed                Active                     0.559728
# Deaths                   Active                     0.527193
#                          Animal fats                0.519321
# Obesity                  Confirmed                  0.514585
# Animal fats              Confirmed                  0.511341
# Recovered                Stimulants                 0.503104
# Meat                     Vegetable Oils            -0.568021
# ...

# %%
df.drop(['Alcoholic Beverages','Meat','Animal fats','Vegetable Oils','Milk - Excluding Butter'],inplace=True,axis=1)

# %%
df_nepal = df[df['Country'] == 'Nepal']

# %%
df_nepal
# Out:
#     Country  Animal Products  Aquatic Products, Other  \
# 107   Nepal          12.1853                      0.0
#
#      Cereals - Excluding Beer    Eggs  Fish, Seafood  Fruits - Excluding Wine  \
# 107                    7.1664  0.4361         0.1563                   0.5513
#
#      Miscellaneous  Offals  Oilcrops  Pulses  Spices  Starchy Roots  \
# 107         0.0082  0.1563    0.4525  0.5513  1.1437         0.1975
#
#      Stimulants  Sugar Crops  Sugar & Sweeteners  Treenuts  Vegetal Products  \
# 107      0.2468       0.1892                 0.0    0.5019           37.8147
#
#      Vegetables  Obesity Undernourished  Confirmed    Deaths  Recovered  \
# 107      0.6006      3.8            8.7   0.906141  0.006784   0.892826
#
#        Active  Population Unit (all except Population)
# 107  0.006531  29996000.0                            %

# %%
df.iloc[107]
# Out:
# Country                              Nepal
# Animal Products                    12.1853
# Aquatic Products, Other                0.0
# Cereals - Excluding Beer            7.1664
# Eggs                                0.4361
# Fish, Seafood                       0.1563
# Fruits - Excluding Wine             0.5513
# Miscellaneous                       0.0082
# Offals                              0.1563
# Oilcrops                            0.4525
# Pulses                              0.5513
# Spices                              1.1437
# Starchy Roots                       0.1975
# Stimulants                          0.2468
# Sugar Crops                         0.1892
# Sugar & Sweeteners                     0.0
# Treenuts                            0.5019
# Vegetal Products                   37.8147
# Vegetables                          0.6006
# Obesity                                3.8
# Undernourished                         8.7
# Confirmed                         0.906141
# ...

# %%
dfff = df.drop(['Country','Confirmed','Deaths','Recovered','Active','Population','Unit (all except Population)'],axis = 1)

# %%
type(dfff)
# Out:
# pandas.core.frame.DataFrame

# %%
dfff
# Out:
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# 0            21.6397                      0.0                    8.0353
# 1            32.0002                      0.0                    2.6734
# 2            14.4175                      0.0                    4.2035
# 3            15.3041                      0.0                    6.5545
# 4            27.7033                      0.0                    3.2153
# ..               ...                      ...                       ...
# 165          16.3261                      0.0                    2.5449
# 166          33.2484                      0.0                    3.7155
# 167          12.5401                      0.0                   11.5271
# 168           9.6005                      0.0                   14.3225
# 169          10.3796                      0.0                    9.7922
#
#        Eggs  Fish, Seafood  Fruits - Excluding Wine  Miscellaneous  Offals  \
# ...

# %%
dfff.iloc[107].astype(float).max()
# Out:
# 37.8147

# %%
plt.figure(figsize=(25,8))
sns.barplot(dfff.iloc[107].keys().astype(str),dfff.iloc[107].values.astype(float))
# Out:
# C:\Users\DELL\anaconda3\envs\deeplnenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
