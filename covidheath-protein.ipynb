# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# This dataset includes percentage of protein intake from different types of food in countries around
# <br>
# the world. The last couple of columns also includes counts of obesity, undernourished, and COVID-19 cases
# <br>
# as percentages of the total population for comparison purposes.
# <br>
# <br>
# Country-Countries around the world
# <br>
# Alcoholic Beverages- Percentage of protein intake from alcoholic beverages
# <br>
# Animal Products - Percentage of protein intake from animal products
# <br>
# Animal fats- Percentage of protein intake from animal fats
# <br>
# Aquatic Products, Other- percentage of protein intake from aquatic products
# <br>
# Cereals - Excluding Beer - Percentage of protein intake from cereals - excluding beer
# <br>
# Eggs- Percentage of protein intake from eggs
# <br>
# Fish, Seafood- Percentage of protein intake from fish, seafood
# <br>
# Fruits - Excluding Wine - Percentage of protein intake from fruits - excluding wine
# <br>
# Meat- Percentage of protein intake from meat

# %%
df = pd.read_csv(r'covid-healthy-diet-dataset/Protein_Supply_Quantity_Data.csv')

# %%
df
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
# ...

# %%
animal_product = df.sort_values(by='Animal Products',ascending=False)[['Country','Animal Products']].head(10)

# %%
animal_product
# Out:
#                       Country  Animal Products
# 67                    Iceland          35.7860
# 10                    Bahamas          34.1684
# 101                  Mongolia          34.0697
# 4         Antigua and Barbuda          33.1901
# 52           French Polynesia          32.9981
# 7                   Australia          32.9787
# 108               Netherlands          32.7073
# 161  United States of America          32.4775
# 39                    Denmark          32.3912
# 128     Saint Kitts and Nevis          32.0169

# %%
#top 10 countries that take highest Percentage of protein from animal products
plt.figure(figsize=(20,8))
sns.barplot(x='Country',y='Animal Products',data=animal_product)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Animal Products'>

# %%
df.isnull().sum()
# Out:
# Country                         0
# Alcoholic Beverages             0
# Animal Products                 0
# Animal fats                     0
# Aquatic Products, Other         0
# Cereals - Excluding Beer        0
# Eggs                            0
# Fish, Seafood                   0
# Fruits - Excluding Wine         0
# Meat                            0
# Milk - Excluding Butter         0
# Offals                          0
# Oilcrops                        0
# Pulses                          0
# Spices                          0
# Starchy Roots                   0
# Stimulants                      0
# Sugar Crops                     0
# Sugar & Sweeteners              0
# Treenuts                        0
# Vegetal Products                0
# Vegetable Oils                  0
# Vegetables                      0
# Miscellaneous                   0
# Obesity                         3
# Undernourished                  7
# Confirmed                       6
# ...

# %%
#top 10 countries that take highest Percentage of proteins from Vegetable Oils
meat = df.sort_values(by='Meat',ascending=False)[['Country','Meat']].head(10)

# %%
meat
# Out:
#                       Country     Meat
# 5                   Argentina  21.6250
# 10                    Bahamas  20.4311
# 101                  Mongolia  19.8082
# 128     Saint Kitts and Nevis  19.6622
# 131                     Samoa  19.3878
# 52           French Polynesia  18.8677
# 7                   Australia  18.8298
# 20                     Brazil  18.7486
# 110               New Zealand  18.0949
# 161  United States of America  18.0875

# %%
plt.figure(figsize=(18,5))
sns.scatterplot(x='Country',y='Meat',data=meat)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Meat'>

# %%
dfCorr = df.corr()
filteredDf = dfCorr[((dfCorr >= .5) | (dfCorr <= -.5)) & (dfCorr !=1.000)]
plt.figure(figsize=(30,10))
sns.heatmap(filteredDf, annot=True, cmap="Reds")
plt.show()

# %%
def corrFilter(x: pd.DataFrame, bound: float):
    xCorr = x.corr()
    xFiltered = xCorr[((xCorr >= bound) | (xCorr <= -bound)) & (xCorr !=1.000)]
    xFlattened = xFiltered.unstack().sort_values(ascending=False).drop_duplicates()
    return xFlattened

corrFilter(df,.5)
# Out:
# Deaths                    Confirmed                   0.861348
# Animal Products           Meat                        0.854029
# Vegetal Products          Cereals - Excluding Beer    0.825928
# Confirmed                 Recovered                   0.820948
# Recovered                 Deaths                      0.671801
# Animal Products           Milk - Excluding Butter     0.649646
# Confirmed                 Milk - Excluding Butter     0.627243
# Obesity                   Animal Products             0.607625
# Eggs                      Animal Products             0.600599
# Obesity                   Meat                        0.596750
# Pulses                    Vegetal Products            0.595260
# Active                    Confirmed                   0.559728
# Animal Products           Confirmed                   0.542936
# Deaths                    Milk - Excluding Butter     0.536765
#                           Active                      0.527193
# ...

# %%
df.drop(['Milk - Excluding Butter','Eggs','Animal Products','Vegetable Oils','Cereals - Excluding Beer'],inplace=True,axis=1)

# %%
df_nepal = df[df['Country'] == 'Nepal']

# %%
df_nepal
# Out:
#     Country  Alcoholic Beverages  Animal fats  Aquatic Products, Other  \
# 107   Nepal               0.0407       0.0271                      0.0
#
#      Fish, Seafood  Fruits - Excluding Wine    Meat  Offals  Oilcrops  Pulses  \
# 107         0.5698                   0.6105  3.1407  0.6919    0.1628  5.0943
#
#      Spices  Starchy Roots  Stimulants  Sugar Crops  Sugar & Sweeteners  \
# 107  1.1328         2.4556      0.1018       0.0814              0.0068
#
#      Treenuts  Vegetal Products  Vegetables  Miscellaneous  Obesity  \
# 107     0.156           41.4055      3.4866         0.0271      3.8
#
#     Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 107            8.7   0.906141  0.006784   0.892826  0.006531  29996000.0
#
#     Unit (all except Population)
# 107                            %

# %%
df.iloc[107]
# Out:
# Country                              Nepal
# Alcoholic Beverages                 0.0407
# Animal fats                         0.0271
# Aquatic Products, Other                0.0
# Fish, Seafood                       0.5698
# Fruits - Excluding Wine             0.6105
# Meat                                3.1407
# Offals                              0.6919
# Oilcrops                            0.1628
# Pulses                              5.0943
# Spices                              1.1328
# Starchy Roots                       2.4556
# Stimulants                          0.1018
# Sugar Crops                         0.0814
# Sugar & Sweeteners                  0.0068
# Treenuts                             0.156
# Vegetal Products                   41.4055
# Vegetables                          3.4866
# Miscellaneous                       0.0271
# Obesity                                3.8
# Undernourished                         8.7
# Confirmed                         0.906141
# ...

# %%
dfff = df.drop(['Country','Confirmed','Deaths','Recovered','Active','Population','Unit (all except Population)'],axis = 1)

# %%
dfff
# Out:
#      Alcoholic Beverages  Animal fats  Aquatic Products, Other  Fish, Seafood  \
# 0                 0.0000       0.0277                   0.0000         0.0647
# 1                 0.1840       0.0711                   0.0000         0.6274
# 2                 0.0323       0.0054                   0.0000         0.6350
# 3                 0.6285       0.0277                   0.0000         5.4436
# 4                 0.1535       0.1289                   0.0000         8.2146
# ..                   ...          ...                      ...            ...
# 165               0.1955       0.1244                   0.0000         2.6477
# 166               0.1555       0.1555                   0.0056         5.7435
# 167               0.0000       0.0188                   0.0000         0.9392
# 168               0.4824       0.0338                   0.0000         3.0126
# 169               0.2929       0.0391                   0.0000         1.0837
#
# ...

# %%
dfff.iloc[107].astype(float).max()
# Out:
# 41.4055

# %%
dfff.iloc[107].astype(float).min()
# Out:
# 0.0

# %%
plt.figure(figsize=(25,8))
sns.barplot(dfff.iloc[107].keys().astype(str),dfff.iloc[107].values.astype(float))
# Out:
# C:\Users\DELL\anaconda3\envs\deeplnenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
